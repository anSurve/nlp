# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Aniket\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
sentence = "her cat's name is luna. her dog's name is murphy."

# %%
sent_tokenize(sentence)
# Out:
# ["her cat's name is luna.", "her dog's name is murphy."]

# %%
print(word_tokenize(sentence))
# Out:
# ['her', 'cat', "'s", 'name', 'is', 'luna', '.', 'her', 'dog', "'s", 'name', 'is', 'murphy', '.']

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()
connected_words = ['connected', 'connecting', 'connect', 'connectivity', 'connects']
for word in connected_words:
    print(word, " : ", ps.stem(word))
# Out:
# connected  :  connect
# connecting  :  connect
# connect  :  connect
# connectivity  :  connect
# connects  :  connect

# %% [markdown]
# ## Lemmatization

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Aniket\AppData\Roaming\nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()
connected_words = ['connected', 'connecting', 'connect', 'connectivity', 'connects']
for word in connected_words:
    print(word, " : ", lemmatizer.lemmatize(word))
